# %%
# !pip install pygmo
# Out:
# ERROR: Could not find a version that satisfies the requirement pygmo
# ERROR: No matching distribution found for pygmo

# %%
from pathlib import Path
import re

import numpy as np
import pandas as pd

try:
    import pygmo
except ImportError:
    pass

# %%
# specify the appropriate path
base = Path.home()

# %%
# useful for toggling display of data
DEBUG = 1
N_SIMULATIONS = 100
N_BEST_LINEUPS = 150

# %%
def fc_lineups_as_binary(df, mapping):
    """Converts dataframe of names to np.ndarray of binary values
       which correspond to indexes in the player projections dataframe"""
    idx = df.applymap(lambda x: mapping.get(x)).values
    return np.sum((np.arange(idx.max() + 1) == idx[...,None]-1).astype(int), axis=1)


def index_mapping(df, col='player'):
    """Creates dict of column_value: index value
       pandas returns dict of index to column value
       so we have to reverse it to get correct mapping
    """
    return {v: k for k, v in df.loc[:, [col]].to_dict()[col].items()}


def parse_fc_names(s):
    """Takes a string and returns a tuple of int, str"""
    patt = re.compile(r'(.*?)[(]{1}(\d+)[)]{1}')
    m = re.search(patt, s)
    name, pid = m.groups()
    return int(pid), name.strip()
    

def process_fc_lineups(fn):
    """Processes lineup file from fantasycruncher
    
    Args:
        fn (str): the full path of the lineup file
        
    Returns:
    
    """   
    # each cell in lineup file has names in format John Smith (111334)
    # we want to convert this to a str
    df = pd.read_csv(fn)
    return df.applymap(lambda x: parse_fc_names(x)[1])

# %%
# STEP ONE: load players
# has columns for player, mean, std
playerfn = base / 'mlbprojections.csv'
players = pd.read_csv(playerfn)

if DEBUG:
    display(players)
# Out:
#                player       mean       std
# 0        Mookie Betts  11.043333  8.069701
# 1        Bryce Harper  10.113333  7.758110
# 2        Corey Seager   9.800000  7.024382
# 3       Shohei Ohtani   9.163333  7.390410
# 4       Justin Turner   9.140000  7.079116
# ..                ...        ...       ...
# 270        Casey Mize  11.466667  7.939764
# 271       Sam Hentges   9.730000  7.741987
# 272       Zach Davies   9.360000  7.942880
# 273  James Kaprielian  10.106667  7.697991
# 274       Justin Dunn   9.226667  7.758289
#
# [275 rows x 3 columns]

# %%
# STEP TWO: read in lineups
lineupfn = base / 'Crunch_1_20210512.csv'
lineups = process_fc_lineups(lineupfn)

if DEBUG:
    display(lineups)
# Out:
#                 P               P.1                  C                1B  \
# 0     Danny Duffy         Max Fried       Andrew Knapp      Rhys Hoskins
# 1     Gerrit Cole       Julio Urias         Manny Pina     Dan Vogelbach
# 2     Gerrit Cole  Brandon Woodruff       Danny Jansen     Shohei Ohtani
# 3     Gerrit Cole         Max Fried    Yasmani Grandal        Jose Abreu
# 4     Gerrit Cole       Julio Urias       Danny Jansen    Carlos Santana
# ...           ...               ...                ...               ...
# 1417  Gerrit Cole  Brandon Woodruff        Sean Murphy        Matt Olson
# 1418  Gerrit Cole       Danny Duffy  Christian Vazquez      Rhys Hoskins
# 1419  Gerrit Cole  Brandon Woodruff  Christian Vazquez    Mitch Moreland
# 1420  Gerrit Cole  Brandon Woodruff        Drew Butera       Jared Walsh
# 1421  Gerrit Cole      Zack Wheeler        Jake Rogers  Asdrubal Cabrera
#
#                    2B               3B               SS                 OF  \
# 0     Marwin Gonzalez        Alec Bohm  Xander Bogaerts      J.D. Martinez
# 1         Jose Altuve     Alex Bregman    Carlos Correa       Lorenzo Cain
# 2       Marcus Semien  Philip Gosselin    Jose Iglesias        Jared Walsh
# 3         Jean Segura     Yoan Moncada    Danny Mendick       Bryce Harper
# 4       Marcus Semien     Cavan Biggio      Bo Bichette  Andrew Benintendi
# ...               ...              ...              ...                ...
# 1417      Jean Segura        Alec Bohm     Elvis Andrus       Bryce Harper
# 1418    Nick Madrigal        Jon Berti  Xander Bogaerts      J.D. Martinez
# 1419     Jordy Mercer   Starlin Castro      Trea Turner          Juan Soto
# 1420    Marcus Semien  Philip Gosselin    Jose Iglesias       Bryce Harper
# 1421      Jean Segura        Alec Bohm   Didi Gregorius       Bryce Harper
#
#                    OF.1              OF.2
# 0          Bryce Harper  Andrew McCutchen
# 1           Kyle Tucker    Chas McCormick
# 2     Teoscar Hernandez       Taylor Ward
# 3      Andrew McCutchen     Andrew Vaughn
# 4           Jorge Soler   Lourdes Gurriel
# ...                 ...               ...
# 1417         Mark Canha  Stephen Piscotty
# 1418     Hunter Renfroe   Franchy Cordero
# 1419   Andrew McCutchen  Andrew Stevenson
# 1420          Juan Soto      Juan Lagares
# 1421   Andrew McCutchen        Mark Canha
#
# [1422 rows x 10 columns]

# %%
# STEP THREE: drop players that aren't in a lineup
# looks like 275 in pool, 160 used in lineups
players_in_lineup = np.unique(lineups.values)
players_used = (
  players
  .loc[players['player'].isin(players_in_lineup), :]
  .reset_index(drop=True)
)

if DEBUG:
    display(players_used)
# Out:
#                 player       mean       std
# 0         Mookie Betts  11.043333  8.069701
# 1         Bryce Harper  10.113333  7.758110
# 2         Corey Seager   9.800000  7.024382
# 3        Shohei Ohtani   9.163333  7.390410
# 4        Justin Turner   9.140000  7.079116
# ..                 ...        ...       ...
# 155  Eduardo Rodriguez  16.400000  8.117445
# 156       Hyun-Jin Ryu  16.210000  8.140971
# 157          Max Fried  15.590000  7.986163
# 158     Dallas Keuchel  12.170000  7.978417
# 159          John Gant  14.146667  7.946639
#
# [160 rows x 3 columns]

# %%
# STEP FOUR: create name-index mapping
player_mapping = index_mapping(players_used, col='player')

if DEBUG:
    print(len(list(player_mapping.keys())))
# Out:
# 160

# %%
# STEP FIVE: convert lineups to np.ndarray
# shape of lineup_ax_idx is (len(lineups), len(players_used))
# so in this example, it is (1422, 160)
lineup_matrix = fc_lineups_as_binary(lineups, player_mapping)

if DEBUG:
    print(lineup_matrix.shape)
# Out:
# (1422, 160)

# %%
# STEP SIX: get randomized projections
# projection ranges is np.ndarray of shape (n_simulations, len(players_used))
projection_ranges = np.random.normal(players_used['mean'], 
                                     players_used['std'], 
                                     size=(N_SIMULATIONS, len(players_used)))

if DEBUG:
    print(projection_ranges.shape)
# Out:
# (100, 160)

# %%
# STEP SEVEN: get lineup scores with randomized projections
lineup_scores = np.array([np.sum((lineup_matrix[i,:] * projection_ranges), axis=1)
                 for i in np.arange(lineup_matrix.shape[0])])

if DEBUG:
    print(lineup_scores.shape)
# Out:
# (1422, 100)

# %%
# STEP EIGHT: summarize lineups
lusumm = pd.DataFrame({'lu_mean': np.mean(lineup_scores, axis=1), 
                       'lu_75': np.percentile(lineup_scores, 75, axis=1),
                       'lu_max': np.max(lineup_scores, axis=1)})

if DEBUG:
    display(lusumm)
# Out:
#          lu_mean       lu_75      lu_max
# 0     101.111293  117.457761  156.233146
# 1      82.810097   97.764073  138.916748
# 2      92.829803  106.607806  157.546521
# 3      85.506175   97.620616  145.100660
# 4      81.384206   93.754038  122.483062
# ...          ...         ...         ...
# 1417   96.318335  114.437308  144.365210
# 1418   81.951933   96.898150  138.649561
# 1419   87.666509  101.721442  125.790100
# 1420   90.791572  106.900639  162.812925
# 1421   96.776658  109.490482  135.722080
#
# [1422 rows x 3 columns]

# %%
# STEP NINE: pick 150 best lineups
try:
    idx_best = pygmo.select_best_N_mo(0 - lusumm.values, 150)
except NameError:
    print('pygmo not installed - Display top lineups by average\n\n')
    idx_best = (-lusumm['lu_mean'].values).argsort()[:N_BEST_LINEUPS]
display(pd.concat([lineups.loc[idx_best], lusumm.loc[idx_best]], axis=1))
# Out:
# pygmo not installed - Display top lineups by average
#                      P               P.1                 C                1B  \
# 41    Brandon Woodruff      Hyun-Jin Ryu      Andrew Knapp      Rhys Hoskins
# 973   Brandon Woodruff      Zack Wheeler      Andrew Knapp     Jesus Aguilar
# 826   Brandon Woodruff       Julio Urias  Martin Maldonado      Rhys Hoskins
# 1194  Brandon Woodruff       Julio Urias  Martin Maldonado       Pavin Smith
# 831   Brandon Woodruff       Danny Duffy      Stephen Vogt  Asdrubal Cabrera
# ...                ...               ...               ...               ...
# 967        Gerrit Cole  Brandon Woodruff       Drew Butera     Shohei Ohtani
# 1324       Gerrit Cole  Brandon Woodruff    Salvador Perez     Dan Vogelbach
# 567        Gerrit Cole  Brandon Woodruff    Salvador Perez        Matt Olson
# 886        Gerrit Cole  Brandon Woodruff       Jake Rogers  Asdrubal Cabrera
# 154        Gerrit Cole  Brandon Woodruff      Andrew Knapp      Rhys Hoskins
#
#                    2B                 3B               SS                 OF  \
# 41        Jean Segura      Rafael Devers   Didi Gregorius       Bryce Harper
# 973         Isan Diaz      Hunter Dozier     Miguel Rojas    Corey Dickerson
# 826       Jose Altuve       Alex Bregman    Carlos Correa  Teoscar Hernandez
# 1194      Jean Segura       Alex Bregman    Carlos Correa     Yordan Alvarez
# 831   Marwin Gonzalez      Rafael Devers       Tyler Wade      J.D. Martinez
# ...               ...                ...              ...                ...
# 967   Whit Merrifield          Alec Bohm    Jose Iglesias        Jared Walsh
# 1324      Kolten Wong        Travis Shaw     Joshua Rojas          Juan Soto
# 567       Jean Segura  Jeimer Candelario     Elvis Andrus     Ramon Laureano
# 886         Isan Diaz      Rafael Devers  Xander Bogaerts       Alex Verdugo
# 154   Eduardo Escobar   Asdrubal Cabrera   Didi Gregorius      David Peralta
#
#                     OF.1              OF.2     lu_mean       lu_75      lu_max
# 41          Alex Verdugo   Franchy Cordero  113.341038  126.194040  172.796683
# 973          Adam Duvall       Pavin Smith  111.618252  124.500923  162.354694
# 826          Kyle Tucker   Franchy Cordero  111.303289  125.215223  166.889530
# 1194         Kyle Tucker       Taylor Ward  111.027849  124.645240  166.587531
# 831         Alex Verdugo   Franchy Cordero  110.109579  125.720168  178.940464
# ...                  ...               ...         ...         ...         ...
# 967     Andrew McCutchen           Jon Jay   96.387023  110.413996  159.519287
# 1324  Jackie Bradley Jr.    Avisail Garcia   96.379571  110.758078  152.284296
# 567           Mark Canha  Stephen Piscotty   96.368911  112.601573  144.839180
# 886       Hunter Renfroe   Franchy Cordero   96.325434  108.777759  143.930713
# 154     Andrew McCutchen    Odubel Herrera   96.320515  109.030515  140.868564
#
# [150 rows x 13 columns]
